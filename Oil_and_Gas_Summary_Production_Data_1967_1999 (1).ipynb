# %% [markdown]
# # Oil and gas example using PANDAS, SQL3, NUMPY and MATPLOTLIB

# %% [markdown]
# ## Reading the data from excel and into a panda data-frame

# %%
import pandas as pd
import numpy as np
import sqlite3

df = pd.read_excel(r'oil-and-gas-summary-production-data-1967-1999.xlsx')
df.head()
# Out:
#    Production Year  ...                                  Location
# 0             1995  ...      BUFFALO, NY\n(42.887691, -78.879374)
# 1             1995  ...   WEST UNION, NY\n(42.094951, -77.725816)
# 2             1994  ...   CARROLLTON, NY\n(42.023289, -78.628438)
# 3             1994  ...  CHEEKTOWAGA, NY\n(42.907071, -78.754318)
# 4             1995  ...     ALLEGANY, NY\n(42.088061, -78.491258)
#
# [5 rows x 20 columns]

# %% [markdown]
# ## Cleaning data

# %% [markdown]
# Cleaning dates (American style) to a datetime value (yyyy/mm/dd)

# %%
import datetime

df['Production Date Entered']
dates = df['Production Date Entered'].tolist()
for i, d in enumerate(dates):
  if type(d) == str:
    month, a, d= d.partition('/')
    day, a, year= d.partition('/')
    dates[i] = datetime.datetime(int(year), int(month), int(day))
    
all(isinstance(d, datetime.datetime) for d in dates)
# Out:
# True

# %% [markdown]
# Replacing values in column

# %%
df['Production Date Entered'] = dates
df.head()
# Out:
#    Production Year  ...                                  Location
# 0             1995  ...      BUFFALO, NY\n(42.887691, -78.879374)
# 1             1995  ...   WEST UNION, NY\n(42.094951, -77.725816)
# 2             1994  ...   CARROLLTON, NY\n(42.023289, -78.628438)
# 3             1994  ...  CHEEKTOWAGA, NY\n(42.907071, -78.754318)
# 4             1995  ...     ALLEGANY, NY\n(42.088061, -78.491258)
#
# [5 rows x 20 columns]

# %% [markdown]
# ## Counting number of entries per year

# %%
py = pd.value_counts(df['Production Year'])
py.sort_index(ascending=True).plot(kind = 'bar', title='Entries per year')

# %% [markdown]
# ## Showing the 5 years with the higher number of entries

# %%
py.sort_values(ascending=True)[-5:].plot(x = 'top 5', y = 'productions per year', kind = 'bar', title='5 years with the higher count of entries')

# %% [markdown]
# ## Counting number of Active Oil Wells per year

# %%
years = np.sort(df['Production Year'].unique())
actOilWells = {}
for y in years:
  prodYear = df['Production Year'] == y
  actOilWells[y] = df[prodYear][['Production Year', 'Active Oil Wells']].sum(axis = 0, skipna = True)[1]
actOilWells
# Out:
# {1967: 4183,
#  1968: 4683,
#  1969: 5304,
#  1970: 5795,
#  1971: 4793,
#  1972: 5508,
#  1973: 5552,
#  1974: 5219,
#  1975: 4844,
#  1976: 5565,
#  1977: 4915,
#  1978: 5154,
#  1979: 5706,
#  1980: 5497,
#  1981: 5098,
#  1982: 4850,
#  1983: 4696,
#  1984: 4930,
#  1985: 4818,
#  1986: 4439,
#  1987: 4195,
#  1988: 4368,
#  1989: 4043,
#  1990: 3916,
#  1991: 3627,
#  1992: 3761,
#  1993: 3785,
#  1994: 3670,
#  1995: 3655,
#  1996: 3684,
#  1997: 3467,
#  1998: 3940,
#  1999: 3815}

# %%
import matplotlib.pyplot as plt


x = [x for x in actOilWells.keys()]
y = [y for y in actOilWells.values()]
highest_year = x[y.index(np.max(y))]
print('Highest year is', highest_year)
plt.bar(x,y, color = 'orange')
plt.title('Active Oils wells per year')
plt.ylabel('Active oil wells')
plt.xlabel('Years')
plt.grid(True)
plt.figure(figsize=(20,20))
plt.show()
# Out:
# Highest year is 1970

# %% [markdown]
# ## Operators with the highest Oil Production

# %%
# Operators with the highest Oil production 

a = df[df['Production Year'] == highest_year][['Operator', 'Oil Produced, bbl']].values
a.sort(axis=0)
a = a[-6:,:]
x = a[:,0]
y = a[:,1]
plt.figure(figsize=(15,5))
plt.title('Operators with the highest Oil production')
plt.ylabel('Oil Produced')
plt.xlabel('Operators')
plt.bar(x,y, color='orange')
plt.show()

# %% [markdown]
# ## Gas production per year

# %%
a = df[['Production Year', 'Production Date Entered', 'Gas Produced, Mcf']].values
years = np.unique(a[:,0])
# find they year with the highest count of gas produced
summation = np.zeros((years.shape[0], 2), dtype=int)
for i, y in enumerate(years):
  summation[i] = [y, np.sum(np.where(a[:,0] == y)[0]),]

# %%
yearHighestGasProd = summation[np.argmax(summation[:,1])][0]
print('Year with highest gas Production : ', yearHighestGasProd)
summation
plt.figure(figsize=(17,5))
plt.title('Gas production per year')
plt.xlabel('years')
plt.ylabel('Gas production')
plt.grid(True)
plt.bar(summation[:,0], summation[:,1], color='red')
# Out:
# Year with highest gas Production :  1993
# <BarContainer object of 33 artists>

# %% [markdown]
# ## Year with the highest gas production, divided by months

# %%
a = df[['Production Year', 'Production Date Entered', 'Gas Produced, Mcf']].values
indexes = np.where(a[:,0] == yearHighestGasProd)
gas_date = a[indexes][:,1:]
gas_month = [[m.month, gas] for m, gas in zip(gas_date[:,0], gas_date[:,1])]
gas_month = np.asarray(gas_month)
print(gas_month.shape)
gas_month
# Out:
# (1372, 2)
# array([[   1,  565],
#        [   2,   79],
#        [   8,    0],
#        ...,
#        [   8,    0],
#        [   3,  469],
#        [   3, 2157]])

# %%
import calendar
summation = np.zeros((12,2), dtype=int)
months = [v for v in calendar.month_abbr][1:]

for i in range(12):
  indexes = np.where(gas_month[:,0] == i+1)
  summation[i] = [i+1, np.sum(gas_month[indexes])]

plt.figure(figsize=(10,5))
plt.title("Gas produced by month in %d" %yearHighestGasProd )
plt.xlabel('Months')
plt.ylabel('Gas produced')
plt.ticklabel_format(style='plain')
plt.bar(months, summation[:,1], color='red')
plt.show()

# %%
explode = [0]*12
explode[0] = 0.11
explode[2] = 0.12
explode[3] = 0.1
plt.figure(figsize=(10,10))
plt.title('Monthly Percentages of gas production in %d' %yearHighestGasProd)
plt.pie(summation[:,1], explode = explode, shadow=True, startangle = 90, labels=months, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Taxable Gas for all years

# %%
taxable_gas = df[['Production Year', 'Taxable Gas, Mcf']].values

summation = []
for y in years:
  indexes = np.where(taxable_gas[:,0] == y)[0]
  summation.append([y, np.sum(taxable_gas[indexes][:,1])])

summation = np.asarray(summation)

plt.figure(figsize=(10,5))
plt.title("Taxable Gas" %yearHighestGasProd )
plt.xlabel('Years')
plt.ylabel('Taxable Gas per year')
plt.ticklabel_format(style='plain')
markerline, stemlines, baseline =  plt.stem(summation[:,0], summation[:,1], linefmt='--g', markerfmt='D', bottom = 1000000, use_line_collection=True)
markerline.set_markerfacecolor('none')
markerline.set_markersize(7)
plt.show()

highestYearTaxGas = summation[np.argmax(summation[:,1])][0]
print('Year with the highest Taxable gas is : %d' %highestYearTaxGas)
# Out:
# Year with the highest Taxable gas is : 1992

# %% [markdown]
# ## Taxable gas by county for the with the highest ammount of taxable gas

# %%
taxable_gas = df[['Production Year', 'County', 'Taxable Gas, Mcf']].values

indexes = np.where(taxable_gas == highestYearTaxGas)[0]
county = taxable_gas[indexes][:,1:]
counties = np.unique(county[:,0])
summation = []

for c in counties:
  indexes = np.where(county[:,0] == c)[0]
  summation.append([c, np.sum(county[indexes][:,1])])
summation = np.asarray(summation)

plt.clf()
plt.figure(figsize=(15,5))
plotbar = plt.bar(counties, summation[:,1].astype(int), color='purple')
plt.title("Taxable Gas in %d by county" %yearHighestGasProd )
plt.xticks(rotation=30, size='small')
plt.xlabel('County')
plt.ylabel('Taxable Gas')
xlocs, xlabs = plt.xticks()
plt.text(xlocs[3]-0.5, summation[:,1][3].astype(int) + 150000, summation[:,1][3].astype(int) )
plt.show()

# %% [markdown]
# ## Saving modified file into SQL data base

# %%
from sqlalchemy import create_engine


engine = create_engine('sqlite://', echo=False)
df.to_sql('oil', con=engine)

# %%
engine.execute("SELECT * FROM oil").fetchall()
# Out:
# [(0, 1995, '1996-03-12 00:00:00.000000', 'Buffalo China, Inc.', 'Erie', 'BUFFALO', 'BUFFALO', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 106, 0, 0, None, 'BUFFALO, NY\n(42.887691, -78.879374)'),
#  (1, 1995, '1996-03-29 00:00:00.000000', 'Copper Ridge Oil, Inc.', 'Steuben', 'WEST UNION', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 28, 0, 0, 0, 7, 0, 'NO', 1229, 0, 180, 0, 'OA', 'WEST UNION, NY\n(42.094951, -77.725816)'),
#  (2, 1994, '1995-02-14 00:00:00.000000', 'White, Walter W. & Christina L.', 'Cattaraugus', 'CARROLLTON', 'BRADFORD', 'BRADFORD', 3, 0, 0, 0, 0, 0, 'NO', 462, 0, 0, 0, 'OA', 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (3, 1994, '1995-01-19 00:00:00.000000', 'Stiegler, Richard M', 'Erie', 'CHEEKTOWAGA', 'BUFFALO', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 530, 0, 0, None, 'CHEEKTOWAGA, NY\n(42.907071, -78.754318)'),
#  (4, 1995, '1996-12-02 00:00:00.000000', 'Bucher, Charles J', 'Cattaraugus', 'ALLEGANY', 'FIVE MILE', 'BRADFORD', 10, 0, 0, 0, 0, 0, 'NO', 45, 0, 80, 0, 'OA', 'ALLEGANY, NY\n(42.088061, -78.491258)'),
#  (5, 1995, '1996-02-04 00:00:00.000000', 'Cotton Well Drilling Company,  Inc.', 'Chautauqua', 'SHERIDAN', 'LAKESHORE', 'MEDINA', 0, 0, 13, 2, 0, 0, 'NO', 0, 27742, 377, 24177, 'GK', 'SHERIDAN, NY\n(42.485764, -79.241801)'),
#  (6, 1994, '1995-05-04 00:00:00.000000', 'Oil, Gas & Land Services, Inc.', 'Chautauqua', 'ELLERY', 'ELLERY', 'ONONDAGA-BASS ISLAND', 1, 3, 1, 0, 0, 0, 'NO', 96, 1582, 730, 1439, 'GX,OA', 'ELLERY, NY\n(42.159868, -79.393216)'),
#  (7, 1994, '1995-03-15 00:00:00.000000', 'Traxler, Joyce', 'Genesee', 'LE ROY', 'UHLEY CORNERS-CALEDONIA', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 500, 0, 0, None, 'LE ROY, NY\n(42.977677, -77.987588)'),
#  (8, 1995, '1996-12-09 00:00:00.000000', 'Cunningham Natural Gas Corp.', 'Allegany', 'WILLING', 'STATE LINE', 'ORISKANY', 0, 0, 1, 3, 0, 0, 'NO', 0, 484927, 0, 484927, 'GX', 'WILLING, NY\n(42.085346, -77.922864)'),
#  (9, 1995, '1996-10-18 00:00:00.000000', 'Crowell, Walter R.', 'Chautauqua', 'VILLENOVA', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 100, 0, 0, None, 'VILLENOVA, NY\n(42.391743, -79.119456)'),
#  (10, 1995, '1996-04-04 00:00:00.000000', 'Belden & Blake Corporation', 'Chautauqua', 'ELLERY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 2351, 107, 2351, 'GX', 'ELLERY, NY\n(42.159868, -79.393216)'),
#  (11, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Genesee', 'STAFFORD', 'ROANOKE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1331, 0, 1331, 'GK', 'STAFFORD, NY\n(42.981656, -78.073476)'),
#  (12, 1994, '1995-03-22 00:00:00.000000', 'Torrey, Martha M.', 'Cattaraugus', 'CARROLLTON', 'BRADFORD', 'CHIPMUNK', 8, 0, 0, 0, 0, 0, 'NO', 287, 0, 480, 0, 'OC', 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (13, 1994, '1995-03-22 00:00:00.000000', 'Weil Resources, Inc.', 'Cattaraugus', 'OTTO', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 758, 0, 758, 'GK', 'OTTO, NY\n(42.35589, -78.832619)'),
#  (14, 1994, '1995-03-20 00:00:00.000000', 'Universal Resources Holdings, Incorporated', 'Chautauqua', 'ARKWRIGHT', 'LAKESHORE', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 10516, 0, 10435, 'GK', 'ARKWRIGHT, NY\n(42.406943, -79.236356)'),
#  (15, 1994, '1995-01-19 00:00:00.000000', 'Wroblewski, Francis M', 'Erie', 'COLDEN', 'GLENWOOD', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'COLDEN, NY\n(42.644234, -78.684775)'),
#  (16, 1994, '1995-06-04 00:00:00.000000', 'Transfuel Resources Co.', 'Chautauqua', 'ELLINGTON', 'LAKESHORE', 'MEDINA', 0, 0, 57, 1, 0, 0, 'NO', 0, 151585, 444, 151585, 'GH', 'ELLINGTON, NY\n(42.215868, -79.108075)'),
#  (17, 1994, '1995-04-04 00:00:00.000000', 'Perry Energy II', 'Wyoming', 'PERRY', 'LEICESTER', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'PERRY, NY\n(42.719701, -78.000751)'),
#  (18, 1995, '1996-09-02 00:00:00.000000', 'Basic Energy Producers, Inc.', 'Chautauqua', 'CHAUTAUQUA', 'LAKESHORE', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 11807, 0, 11807, 'GK', 'CHAUTAUQUA, NY\n(42.251704, -79.501693)'),
#  (19, 1995, '1996-03-04 00:00:00.000000', 'Belden & Blake Corporation', 'Chautauqua', 'ARKWRIGHT', 'LAKESHORE', 'MEDINA', 0, 0, 69, 7, 0, 0, 'YES', 0, 107837, 1823, 107837, 'GK', 'ARKWRIGHT, NY\n(42.406943, -79.236356)'),
#  (20, 1994, '1995-05-04 00:00:00.000000', 'United States Gypsum Co.', 'Wyoming', 'SHELDON', 'SHELDON', 'MEDINA', 0, 0, 30, 0, 0, 0, 'NO', 0, 40509, 856, 35497, 'GR', 'SHELDON, NY\n(42.737258, -78.418146)'),
#  (21, 1995, '1996-01-24 00:00:00.000000', 'Estate of Gary W. George', 'Wyoming', 'BENNINGTON', 'DANLEY CORNERS', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'BENNINGTON, NY\n(42.837023, -78.397809)'),
#  (22, 1994, '1995-02-17 00:00:00.000000', 'Potter & Childs', 'Allegany', 'INDEPENDENCE', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 2, 1, 0, 0, 0, 0, 'NO', 155, 0, 0, 0, 'OC', 'INDEPENDENCE, NY\n(42.088045, -77.781386)'),
#  (23, 1994, '1995-03-22 00:00:00.000000', 'Weil Resources, Inc.', 'Erie', 'ORCHARD PARK', 'WEST SENECA', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 4465, 0, 4465, 'GK', 'ORCHARD PARK, NY\n(42.767456, -78.743906)'),
#  (24, 1995, '1996-10-17 00:00:00.000000', 'Capron, Lee H. and Elsie', 'Chautauqua', 'BUSTI', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (25, 1994, '1995-05-06 00:00:00.000000', 'Subsea Oil & Gas, Inc.', 'Erie', 'HAMBURG', 'LAKEVIEW', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'HAMBURG, NY\n(42.723291, -78.839026)'),
#  (26, 1995, '1996-02-04 00:00:00.000000', 'Evans-Brant (Lake Shore) Central School District', 'Erie', 'EVANS', 'LAKEVIEW', 'MEDINA', 0, 0, 4, 0, 0, 0, 'YES', 0, 10575, 241, 0, None, 'EVANS, NY\n(42.638457, -79.027689)'),
#  (27, 1995, '1996-02-29 00:00:00.000000', 'Densmore, Winfield F. & Debra', 'Chautauqua', 'BUSTI', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 250, 0, 0, None, 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (28, 1994, '1995-09-28 00:00:00.000000', 'Walchli, John W. Jr.', 'Steuben', 'WEST UNION', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 5, 2, 0, 0, 0, 0, 'NO', 41, 1471, 58, 1471, 'GK,OC', 'WEST UNION, NY\n(42.094951, -77.725816)'),
#  (29, 1995, '1996-02-04 00:00:00.000000', 'Cotton Well Drilling Company,  Inc.', 'Erie', 'NORTH COLLINS', 'NORTH COLLINS', 'AKRON', 0, 0, 1, 0, 0, 0, 'YES', 0, 100, 0, 0, None, 'NORTH COLLINS, NY\n(42.595159, -78.940951)'),
#  (30, 1995, '1996-03-25 00:00:00.000000', 'Arrowhead Gas Producers, Inc.', 'Chautauqua', 'ELLICOTT', 'LAKESHORE', 'MEDINA', 0, 0, 4, 0, 0, 0, 'NO', 0, 2570, 45, 2570, 'GH', 'ELLICOTT, NY\n(42.734402, -78.731697)'),
#  (31, 1994, '1995-05-04 00:00:00.000000', 'United States Gypsum Co.', 'Genesee', 'PEMBROKE', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 6624, 0, 6583, 'GR', 'PEMBROKE, NY\n(42.997549, -78.435048)'),
#  (32, 1994, '1995-05-04 00:00:00.000000', 'U S Energy Development Corp.', 'Chautauqua', 'CHARLOTTE', 'GERRY-CHARLOTTE', 'ONONDAGA-BASS ISLAND', 1, 1, 0, 0, 0, 0, 'NO', 0, 2271, 5, 2271, 'GH', 'CHARLOTTE, NY\n(43.255001, -77.617203)'),
#  (33, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'LANCASTER', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 5, 1, 0, 0, 'NO', 0, 26041, 0, 25492, 'GK', 'LANCASTER, NY\n(42.892784, -78.676417)'),
#  (34, 1995, '1996-09-01 00:00:00.000000', 'Arkema Inc.', 'Erie', 'TONAWANDA', 'BUFFALO', 'MEDINA', 0, 0, 3, 0, 0, 0, 'YES', 0, 1200, 0, 0, None, 'TONAWANDA, NY\n(43.016642, -78.878854)'),
#  (35, 1995, '1996-02-16 00:00:00.000000', 'Ebenezer Oil Co., Inc.', 'Allegany', 'ANDOVER', 'ANDOVER', 'FULMER VALLEY', 6, 0, 0, 0, 0, 0, 'NO', 404, 0, 2020, 0, 'OC', 'ANDOVER, NY\n(42.156405, -77.795231)'),
#  (36, 1994, '1995-01-27 00:00:00.000000', 'Seneca Stone Corp.', 'Seneca', 'FAYETTE', 'FAYETTE-WATERLOO', 'QUEENSTON', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'FAYETTE, NY\n(42.831987, -76.847469)'),
#  (37, 1995, '1996-04-17 00:00:00.000000', 'Ardent Resources, Inc.', 'Livingston', 'LEICESTER', 'LEICESTER', 'MEDINA', 0, 0, 2, 3, 0, 0, 'NO', 0, 1352, 0, 1352, 'GH', 'LEICESTER, NY\n(42.772104, -77.898295)'),
#  (38, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Genesee', 'DARIEN', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 7, 0, 0, 0, 'NO', 0, 29563, 0, 28904, 'GK', 'DARIEN, NY\n(42.902048, -78.350767)'),
#  (39, 1994, '1995-02-22 00:00:00.000000', 'Pennzoil Products Co.', 'Cattaraugus', 'ALLEGANY', 'BRADFORD', 'BRADFORD', 0, 65, 0, 0, 72, 0, 'INACTIVE', 0, 0, 0, 0, None, 'ALLEGANY, NY\n(42.088061, -78.491258)'),
#  (40, 1994, '1995-01-27 00:00:00.000000', 'Rose State Custom Service, Inc', 'Cayuga', 'SPRINGPORT', 'WEST AUBURN', 'QUEENSTON', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'SPRINGPORT, NY\n(42.842233, -76.691958)'),
#  (41, 1995, '1996-04-04 00:00:00.000000', 'Evinczik, Joseph A', 'Chautauqua', 'BUSTI', 'BUSTI', 'GLADE', 0, 1, 0, 2, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (42, 1994, '1995-01-25 00:00:00.000000', 'Shorewood Farms Drilling', 'Erie', 'HAMBURG', 'LAKEVIEW', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 1000, 0, 0, None, 'HAMBURG, NY\n(42.723291, -78.839026)'),
#  (43, 1995, '1996-03-26 00:00:00.000000', 'Columbia Natural Resources  LLC', 'Chautauqua', 'CHAUTAUQUA', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 2923, 69, 2923, 'GH', 'CHAUTAUQUA, NY\n(42.251704, -79.501693)'),
#  (44, 1994, '1995-02-03 00:00:00.000000', 'Tenhuisen, Paul Calvin and Josephine', 'Chautauqua', 'CLYMER', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'CLYMER, NY\n(42.02082, -79.629966)'),
#  (45, 1994, '1995-03-02 00:00:00.000000', 'Smith,  Alice E.', 'Cayuga', 'OWASCO', 'AUBURN', 'QUEENSTON', 0, 0, 1, 0, 0, 0, 'YES', 0, 400, 0, 0, None, 'OWASCO, NY\n(42.854988, -76.464778)'),
#  (46, 1994, '1995-03-30 00:00:00.000000', 'Pan Energy Company, Inc.', 'Erie', 'CONCORD', 'CONCORD', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 694, 0, 694, 'GK', 'CONCORD, NY\n(42.535259, -78.731387)'),
#  (47, 1995, '1996-03-19 00:00:00.000000', 'Eagle Oil', 'Allegany', 'ALMA', 'RICHBURG', 'RICHBURG', 0, 10, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'ALMA, NY\n(42.012207, -78.060759)'),
#  (48, 1994, '2001-08-15 00:00:00.000000', 'Seneca Resources Corporation', 'Allegany', 'ALMA', 'SHARON', 'RICHBURG', 0, 0, 2, 0, 0, 0, 'NO', 0, 219, 0, 219, 'GK', 'ALMA, NY\n(42.012207, -78.060759)'),
#  (49, 1995, '1996-12-09 00:00:00.000000', 'Cunningham Natural Gas Corp.', 'Steuben', 'HOWARD', 'DRY WILDCAT', None, 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'HOWARD, NY\n(42.363282, -77.516098)'),
#  (50, 1995, '1996-02-13 00:00:00.000000', 'Clark, Donald C', 'Wyoming', 'PERRY', 'LEICESTER', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 135, 0, 0, None, 'PERRY, NY\n(42.719701, -78.000751)'),
#  (51, 1994, '1995-03-22 00:00:00.000000', 'Weil Resources, Inc.', 'Cattaraugus', 'EAST OTTO', 'LAKESHORE', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 2346, 0, 2125, 'GK', 'EAST OTTO, NY\n(42.389841, -78.755024)'),
#  (52, 1994, '1995-02-03 00:00:00.000000', 'Wyckoff Development Co.', 'Steuben', 'JASPER', 'WYCKOFF', 'ORISKANY', 0, 0, 1, 1, 0, 0, 'NO', 0, 38756, 10, 38756, 'GK', 'JASPER, NY\n(42.12254, -77.503328)'),
#  (53, 1994, '1995-03-03 00:00:00.000000', 'North Central Oil Corp.', 'Cattaraugus', 'LEON', 'LAKESHORE', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 26555, 0, 25529, 'GH', 'LEON, NY\n(42.293071, -79.01636)'),
#  (54, 1994, '1995-03-22 00:00:00.000000', 'Ruel Energy,  Inc.', 'Erie', 'BRANT', 'BRANT-EDEN', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1684, 5, 1684, 'GK', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (55, 1994, '1995-01-25 00:00:00.000000', 'Sherwood, Helen', 'Cattaraugus', 'ALLEGANY', 'CHIPMUNK', 'CHIPMUNK', 9, 0, 0, 0, 0, 0, 'NO', 23, 0, 0, 0, 'OC', 'ALLEGANY, NY\n(42.088061, -78.491258)'),
#  (56, 1994, '1995-08-09 00:00:00.000000', 'Woolson, Arthur A. and Faith S', 'Chautauqua', 'ARKWRIGHT', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 100, 0, 0, None, 'ARKWRIGHT, NY\n(42.406943, -79.236356)'),
#  (57, 1994, '1995-01-31 00:00:00.000000', 'Quebecor Printing Buffalo, Inc', 'Erie', 'CHEEKTOWAGA', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 0, 3, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'CHEEKTOWAGA, NY\n(42.907071, -78.754318)'),
#  (58, 1994, '1995-07-03 00:00:00.000000', 'Thropp, Gregory J', 'Cattaraugus', 'OLEAN', 'FIVE MILE', 'BRADFORD', 10, 0, 0, 0, 0, 0, 'NO', 193, 0, 20, 0, 'OA', 'OLEAN, NY\n(42.077495, -78.429849)'),
#  (59, 1994, '1995-07-28 00:00:00.000000', 'Village of Depew', 'Erie', 'LANCASTER', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 3, 0, 0, 0, 'YES', 0, 23672, 0, 0, None, 'LANCASTER, NY\n(42.892784, -78.676417)'),
#  (60, 1994, '1995-06-04 00:00:00.000000', 'Ripley State Line Truck Stop, Inc.', 'Chautauqua', 'RIPLEY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 100, 0, 0, None, 'RIPLEY, NY\n(42.266859, -79.710476)'),
#  (61, 1995, '1996-03-19 00:00:00.000000', 'Excel Industries, Inc.', 'Erie', 'NEWSTEAD', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'NEWSTEAD, NY\n(43.021136, -78.495603)'),
#  (62, 1995, '1996-02-27 00:00:00.000000', 'Cone Brothers', 'Genesee', 'STAFFORD', 'ROANOKE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 364, 0, 0, None, 'STAFFORD, NY\n(42.981656, -78.073476)'),
#  (63, 1995, '1996-04-17 00:00:00.000000', 'CNG Transmission Corp.', 'Allegany', 'ALMA', 'STATE LINE', 'ORISKANY', 0, 0, 2, 0, 0, 0, 'NO', 0, 6332, 0, 6332, 'GI', 'ALMA, NY\n(42.012207, -78.060759)'),
#  (64, 1995, '2001-08-27 00:00:00.000000', 'BDH Oil, Inc.', 'Cattaraugus', 'ALLEGANY', 'CHIPMUNK', 'CHIPMUNK & BRADFORD 2ND', 162, 0, 0, 0, 154, 0, 'NO', 21260, 0, 1399, 0, 'OC', 'ALLEGANY, NY\n(42.088061, -78.491258)'),
#  (65, 1995, '1996-01-30 00:00:00.000000', 'Brooklyn Union Gas Co.', 'Queens', 'QUEENS', None, None, 0, 0, 0, 5, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'QUEENS, NY\n(40.759776, -73.817302)'),
#  (66, 1994, '1995-05-04 00:00:00.000000', 'Texas Keystone, Inc.', 'Cattaraugus', 'OTTO', 'LAKESHORE', 'MEDINA', 0, 0, 39, 0, 0, 0, 'NO', 0, 69103, 0, 69103, 'GK', 'OTTO, NY\n(42.35589, -78.832619)'),
#  (67, 1995, '1996-01-18 00:00:00.000000', 'All Saints Lutheran Church', 'Erie', 'HAMBURG', 'ORCHARD PARK-HAMBURG', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 384, 0, 0, None, 'HAMBURG, NY\n(42.723291, -78.839026)'),
#  (68, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'ALDEN', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 6, 1, 0, 0, 'NO', 0, 12577, 0, 11856, 'GK', 'ALDEN, NY\n(42.900146, -78.4922)'),
#  (69, 1994, '1995-03-21 00:00:00.000000', 'White, William J', 'Allegany', 'BOLIVAR', 'RICHBURG', 'RICHBURG', 0, 2, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'BOLIVAR, NY\n(42.066701, -78.167667)'),
#  (70, 1995, '1996-02-26 00:00:00.000000', 'Blessing, Michael R.', 'Cattaraugus', 'OLEAN', 'BRADFORD', 'BRADFORD', 0, 3, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'OLEAN, NY\n(42.077495, -78.429849)'),
#  (71, 1995, '1996-10-01 00:00:00.000000', 'Crist, George', 'Allegany', 'SCIO', 'RICHBURG', 'RICHBURG', 2, 0, 0, 0, 0, 0, 'NO', 31, 0, 0, 0, 'OC', 'SCIO, NY\n(42.171429, -77.97865)'),
#  (72, 1995, '1996-09-01 00:00:00.000000', 'Davis, Roy C. Jr.', 'Steuben', 'CAMERON', 'JASPER', 'ORISKANY', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'CAMERON, NY\n(42.199153, -77.406364)'),
#  (73, 1995, '1996-02-26 00:00:00.000000', 'Baker & Odonnell Dev. Co.', 'Allegany', 'ALMA', "FORD'S BROOK", 'RICHBURG', 0, 28, 0, 0, 19, 0, 'INACTIVE', 0, 0, 0, 0, None, 'ALMA, NY\n(42.012207, -78.060759)'),
#  (74, 1994, '1995-03-22 00:00:00.000000', 'Weil Resources, Inc.', 'Erie', 'EDEN', 'BRANT-EDEN', 'MEDINA', 0, 0, 4, 0, 0, 0, 'NO', 0, 2949, 13, 2949, 'GK', 'EDEN, NY\n(42.652413, -78.896936)'),
#  (75, 1995, '1996-04-22 00:00:00.000000', 'Degitz, Sig', 'Cattaraugus', 'CARROLLTON', 'BRADFORD', 'BRADFORD', 1, 0, 0, 0, 0, 0, 'NO', 84, 0, 4, 0, 'OA', 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (76, 1994, '1995-02-22 00:00:00.000000', 'Pennzoil Products Co.', 'Cattaraugus', 'CARROLLTON', 'BRADFORD', 'BRADFORD', 0, 6, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (77, 1994, '2001-08-15 00:00:00.000000', 'Seneca Resources Corporation', 'Allegany', 'ALMA', 'SHARON', 'UPPER DEVONIAN', 0, 0, 25, 0, 0, 0, 'NO', 0, 5102, 0, 5102, 'GK', 'ALMA, NY\n(42.012207, -78.060759)'),
#  (78, 1994, '1995-12-04 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'NORTH COLLINS', 'NORTH COLLINS', 'ORISKANY', 0, 0, 1, 0, 0, 0, 'YES', 0, 228, 0, 0, None, 'NORTH COLLINS, NY\n(42.595159, -78.940951)'),
#  (79, 1994, '1995-05-04 00:00:00.000000', 'United States Gypsum Co.', 'Genesee', 'BATAVIA', 'INDIAN FALLS', 'MEDINA', 0, 0, 16, 1, 0, 0, 'NO', 0, 36731, 260, 34517, 'GR', 'BATAVIA, NY\n(42.99691, -78.186028)'),
#  (80, 1995, '1996-08-11 00:00:00.000000', 'Benson, Ruth J.', 'Allegany', 'GENESEE', 'RICHBURG', 'RICHBURG', 0, 1, 0, 0, 0, 0, 'YES', 0, 5, 0, 0, None, 'GENESEE, NY\n(42.02693, -78.205893)'),
#  (81, 1995, '1996-02-04 00:00:00.000000', 'Cotton Well Drilling Company,  Inc.', 'Chautauqua', 'CHAUTAUQUA', 'LAKESHORE', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 445, 140, 378, 'GK', 'CHAUTAUQUA, NY\n(42.251704, -79.501693)'),
#  (82, 1995, '1996-09-01 00:00:00.000000', 'Dresser Industrial Park, Inc.', 'Erie', 'LANCASTER', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'LANCASTER, NY\n(42.892784, -78.676417)'),
#  (83, 1994, '1995-05-04 00:00:00.000000', 'U S Energy Development Corp.', 'Chautauqua', 'NORTH HARMONY', 'LAKESHORE', 'MEDINA', 0, 0, 13, 3, 0, 0, 'NO', 0, 78888, 2459, 78888, 'GH', 'NORTH HARMONY, NY\n(42.094296, -79.374999)'),
#  (84, 1994, '1995-05-04 00:00:00.000000', 'United States Gypsum Co.', 'Genesee', 'DARIEN', 'HURON CREEK', 'MEDINA', 0, 0, 72, 0, 0, 0, 'NO', 0, 180621, 766, 170044, 'GR', 'DARIEN, NY\n(42.902048, -78.350767)'),
#  (85, 1994, '1995-03-30 00:00:00.000000', 'Pan Energy Company, Inc.', 'Erie', 'BRANT', 'LAKEVIEW', 'MEDINA', 0, 0, 5, 0, 0, 0, 'NO', 0, 1848, 0, 1648, 'GK', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (86, 1995, '1996-11-26 00:00:00.000000', 'Bower, Edwin L.', 'Livingston', 'NUNDA', 'HUNT HOLLOW', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'NUNDA, NY\n(42.579285, -77.939761)'),
#  (87, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Chautauqua', 'POMFRET', 'LAKESHORE', 'MEDINA', 0, 0, 7, 0, 0, 0, 'NO', 0, 22543, 12, 21478, 'GK', 'POMFRET, NY\n(42.439996, -79.331441)'),
#  (88, 1994, '1995-06-04 00:00:00.000000', 'Rupp, Harriett E.', 'Cattaraugus', 'PERRYSBURG', 'LAKESHORE', 'MEDINA', 0, 0, 2, 0, 0, 0, 'YES', 0, 80, 0, 0, None, 'PERRYSBURG, NY\n(42.460246, -79.002177)'),
#  (89, 1994, '1995-01-20 00:00:00.000000', 'Oonk, Harvey', 'Chautauqua', 'CLYMER', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'CLYMER, NY\n(42.02082, -79.629966)'),
#  (90, 1995, '1996-01-16 00:00:00.000000', 'Brown, Edward J. and Anne D.', 'Seneca', 'FAYETTE', 'ROSE HILL', 'QUEENSTON', 0, 0, 1, 0, 0, 0, 'YES', 0, 200, 0, 0, None, 'FAYETTE, NY\n(42.831987, -76.847469)'),
#  (91, 1995, '1996-02-27 00:00:00.000000', 'Collins Oil Co.', 'Allegany', 'SCIO', 'RICHBURG', 'RICHBURG', 31, 0, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'SCIO, NY\n(42.171429, -77.97865)'),
#  (92, 1995, '1996-02-15 00:00:00.000000', 'Desert Gas Exploration, Inc.', 'Chautauqua', 'POMFRET', 'LAKESHORE', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'POMFRET, NY\n(42.439996, -79.331441)'),
#  (93, 1994, '1995-09-05 00:00:00.000000', 'Saint Barnabas R.C. Church', 'Erie', 'CHEEKTOWAGA', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 3, 0, 0, None, 'CHEEKTOWAGA, NY\n(42.907071, -78.754318)'),
#  (94, 1994, '1995-01-19 00:00:00.000000', 'Rohm, Robert F. Jr.', 'Chautauqua', 'NORTH HARMONY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'NORTH HARMONY, NY\n(42.094296, -79.374999)'),
#  (95, 1995, '1996-02-20 00:00:00.000000', 'Alden Aurora Gas Co.,  Inc.', 'Erie', 'NEWSTEAD', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 1, 1, 0, 0, 'YES', 0, 227, 0, 0, None, 'NEWSTEAD, NY\n(43.021136, -78.495603)'),
#  (96, 1995, '1996-04-17 00:00:00.000000', 'Ardent Resources, Inc.', 'Ontario', 'PHELPS', 'MELVIN HILL', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'PHELPS, NY\n(42.957774, -77.057956)'),
#  (97, 1994, '1995-05-04 00:00:00.000000', 'United States Gypsum Co.', 'Erie', 'ALDEN', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 4, 0, 0, 0, 'NO', 0, 16695, 10, 16317, 'GR', 'ALDEN, NY\n(42.900146, -78.4922)'),
#  (98, 1994, '1995-02-15 00:00:00.000000', 'Reserve Gas Company, Inc.', 'Erie', 'ALDEN', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 15, 4, 0, 0, 'NO', 0, 12092, 400, 9973, 'GN', 'ALDEN, NY\n(42.900146, -78.4922)'),
#  (99, 1994, '1995-07-04 00:00:00.000000', 'Vineyard Oil & Gas Company', 'Chautauqua', 'NORTH HARMONY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 4010, 195, 4010, 'GH', 'NORTH HARMONY, NY\n(42.094296, -79.374999)'),
#  (100, 1994, '1995-05-04 00:00:00.000000', 'U S Energy Development Corp.', 'Chautauqua', 'WESTFIELD', 'LAKESHORE', 'MEDINA', 0, 0, 19, 0, 0, 0, 'NO', 0, 76204, 292, 75333, 'GH', 'WESTFIELD, NY\n(42.324884, -79.573821)'),
#  (101, 1995, '1996-02-29 00:00:00.000000', 'East Resources, Inc.', 'Allegany', 'INDEPENDENCE', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'INDEPENDENCE, NY\n(42.088045, -77.781386)'),
#  (102, 1994, '1995-06-04 00:00:00.000000', 'Permclip Products Corporation', 'Erie', 'TONAWANDA', 'BUFFALO', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'TONAWANDA, NY\n(43.016642, -78.878854)'),
#  (103, 1994, '1995-03-27 00:00:00.000000', 'Resource America, Inc.', 'Chautauqua', 'SHERMAN', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 3777, 242, 3777, 'GH', 'SHERMAN, NY\n(42.159351, -79.595176)'),
#  (104, 1995, '1996-04-17 00:00:00.000000', 'Ardent Resources, Inc.', 'Chautauqua', 'HARMONY', 'LAKESHORE', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 3581, 0, 3581, 'GH', 'HARMONY, NY\n(42.074924, -79.486378)'),
#  (105, 1994, '1995-03-04 00:00:00.000000', 'Schreiner Oil and Gas Inc.', 'Chautauqua', 'WESTFIELD', 'LAKESHORE', 'MEDINA', 0, 0, 13, 1, 0, 0, 'NO', 0, 155149, 0, 152349, 'GX', 'WESTFIELD, NY\n(42.324884, -79.573821)'),
#  (106, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Allegany', 'INDEPENDENCE', 'BEECH HILL-INDEPENDENCE', 'PENNY & FULMER VALLEY', 0, 0, 0, 4, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'INDEPENDENCE, NY\n(42.088045, -77.781386)'),
#  (107, 1995, '1996-04-17 00:00:00.000000', 'Ardent Resources, Inc.', 'Tioga', 'OWEGO', 'CAFFERTY HILL', 'MARCELLUS', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'OWEGO, NY\n(42.103237, -76.263163)'),
#  (108, 1995, '1996-01-18 00:00:00.000000', 'Dubisz, Lorraine', 'Erie', 'ELMA', 'BUFFALO CREEK', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'ELMA, NY\n(42.822476, -78.636722)'),
#  (109, 1994, '1995-06-04 00:00:00.000000', 'Transfuel Resources Co.', 'Chautauqua', 'HARMONY', 'LAKESHORE', 'MEDINA', 0, 0, 9, 0, 0, 0, 'NO', 0, 28678, 1082, 28678, 'GH,GK', 'HARMONY, NY\n(42.074924, -79.486378)'),
#  (110, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Cattaraugus', 'LEON', 'LAKESHORE', 'MEDINA', 0, 0, 8, 0, 0, 0, 'NO', 0, 44336, 121, 44076, 'GH', 'LEON, NY\n(42.293071, -79.01636)'),
#  (111, 1994, '1995-04-24 00:00:00.000000', "O'Shanter Resources,  Inc.", 'Chautauqua', 'ELLERY', 'ELLERY', 'MEDINA', 0, 0, 8, 0, 0, 0, 'NO', 0, 10952, 550, 10952, 'GK', 'ELLERY, NY\n(42.159868, -79.393216)'),
#  (112, 1994, '1995-05-04 00:00:00.000000', 'Oil, Gas & Land Services, Inc.', 'Chautauqua', 'GERRY', 'LAKESHORE', 'MEDINA', 0, 0, 31, 4, 0, 0, 'NO', 0, 115748, 1379, 113551, 'GC,GX', 'GERRY, NY\n(42.194749, -79.250394)'),
#  (113, 1995, '1996-02-20 00:00:00.000000', 'Decker, James K. & Tiffany J.', 'Chautauqua', 'BUSTI', 'BUSTI', 'GLADE', 26, 0, 0, 0, 0, 0, 'NO', 1308, 0, 0, 0, 'OA', 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (114, 1994, '1995-07-02 00:00:00.000000', 'Stein, Paul E. & Sons', 'Livingston', 'CALEDONIA', 'UHLEY CORNERS-CALEDONIA', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'CALEDONIA, NY\n(42.973152, -77.855225)'),
#  (115, 1994, '1995-03-24 00:00:00.000000', 'Symbol Oil Corp.', 'Erie', 'BRANT', 'BRANT-EDEN', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 2129, 0, 1925, 'GK', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (116, 1994, '1995-03-22 00:00:00.000000', 'Seneca Resources Corporation', 'Cattaraugus', 'DAYTON', 'LAKESHORE', 'MEDINA', 0, 0, 17, 0, 0, 0, 'NO', 0, 42241, 82, 39848, 'GK', 'DAYTON, NY\n(42.399022, -79.003431)'),
#  (117, 1994, '1995-04-24 00:00:00.000000', "O'Shanter Resources,  Inc.", 'Chautauqua', 'NORTH HARMONY', 'LAKESHORE', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 8680, 280, 8680, 'GX', 'NORTH HARMONY, NY\n(42.094296, -79.374999)'),
#  (118, 1995, '1996-02-15 00:00:00.000000', 'Altimus & Associates', 'Cattaraugus', 'CARROLLTON', 'BRADFORD', 'CHIPMUNK', 2, 0, 0, 0, 0, 0, 'NO', 10, 0, 9, 0, 'OC', 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (119, 1995, '1996-02-04 00:00:00.000000', 'Doolittle, Ruth', 'Livingston', 'YORK', 'UHLEY CORNERS-CALEDONIA', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'YORK, NY\n(42.871099, -77.885584)'),
#  (120, 1994, '1995-02-28 00:00:00.000000', 'Trahan Petroleum, Inc.', 'Chautauqua', 'BUSTI', 'LAKESHORE', 'MEDINA', 0, 0, 4, 1, 0, 0, 'NO', 0, 7317, 0, 7174, 'GK', 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (121, 1995, '1996-03-04 00:00:00.000000', 'Bounty Holdings, Incorporated', 'Chautauqua', 'BUSTI', 'LAKESHORE', 'MEDINA', 0, 0, 4, 2, 0, 0, 'NO', 0, 5728, 35, 4928, 'GK', 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (122, 1994, '1995-07-04 00:00:00.000000', 'Open Flow Gas Supply Corp.', 'Erie', 'BRANT', 'LAKEVIEW', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 11885, 80, 11681, 'GK', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (123, 1995, '1996-02-15 00:00:00.000000', 'Altimus & Associates', 'Allegany', 'GENESEE', 'RICHBURG', 'RICHBURG', 12, 6, 0, 0, 0, 0, 'NO', 78, 0, 28, 0, 'OC', 'GENESEE, NY\n(42.02693, -78.205893)'),
#  (124, 1995, '1996-03-18 00:00:00.000000', 'Eastern States Energy, Inc.', 'Erie', 'LANCASTER', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 5, 0, 0, 0, 'NO', 0, 10327, 0, 10327, 'GK', 'LANCASTER, NY\n(42.892784, -78.676417)'),
#  (125, 1995, '1996-04-04 00:00:00.000000', 'Belden & Blake Corporation', 'Chautauqua', 'MINA', 'LAKESHORE', 'MEDINA', 0, 0, 49, 10, 0, 0, 'YES', 0, 65874, 1189, 65874, 'GX', 'MINA, NY\n(42.130114, -79.694407)'),
#  (126, 1994, '1995-03-15 00:00:00.000000', 'Otis Eastern Service, Inc.', 'Allegany', 'ANDOVER', 'BEECH HILL-INDEPENDENCE', 'PENNY & FULMER VALLEY', 11, 0, 0, 0, 0, 0, 'NO', 364, 140, 3, 0, 'OC', 'ANDOVER, NY\n(42.156405, -77.795231)'),
#  (127, 1994, '1995-03-20 00:00:00.000000', 'Universal Resources Holdings, Incorporated', 'Chautauqua', 'ELLERY', 'LAKESHORE', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 6881, 0, 6881, 'GK', 'ELLERY, NY\n(42.159868, -79.393216)'),
#  (128, 1995, '1996-02-04 00:00:00.000000', 'Basic Energy Producers, Inc.', 'Chautauqua', 'PORTLAND', 'LAKESHORE', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'PORTLAND, NY\n(42.379838, -79.467344)'),
#  (129, 1994, '1995-02-02 00:00:00.000000', 'Plants and Goodwin, Inc.', 'Allegany', 'WIRT', 'RICHBURG', 'RICHBURG', 39, 0, 0, 0, 0, 0, 'NO', 495, 0, 1485, 0, 'OC', 'WIRT, NY\n(42.137408, -78.150594)'),
#  (130, 1994, '1995-06-03 00:00:00.000000', 'Rotunda Estate, Sandy', 'Chautauqua', 'POMFRET', 'LAKESHORE', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'POMFRET, NY\n(42.439996, -79.331441)'),
#  (131, 1994, '1995-09-03 00:00:00.000000', 'Yahn & Yahn, Inc.', 'Steuben', 'WEST UNION', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 31, 2, 0, 0, 0, 0, 'NO', 1489, 360, 1550, 0, 'OC', 'WEST UNION, NY\n(42.094951, -77.725816)'),
#  (132, 1994, '1995-06-14 00:00:00.000000', 'Plants and Goodwin, Inc.', 'Allegany', 'BOLIVAR', 'RICHBURG', 'UPPER DEVONIAN', 0, 0, 1, 0, 0, 0, 'YES', 0, 3, 0, 0, None, 'BOLIVAR, NY\n(42.066701, -78.167667)'),
#  (133, 1994, '1995-03-04 00:00:00.000000', 'Schreiner Oil and Gas Inc.', 'Chautauqua', 'HANOVER', 'LAKESHORE', 'MEDINA', 0, 0, 9, 2, 0, 0, 'NO', 0, 77117, 0, 75317, 'GX', 'HANOVER, NY\n(42.9669, -75.378098)'),
#  (134, 1994, '1995-01-12 00:00:00.000000', 'Seibel, William E', 'Erie', 'LANCASTER', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'LANCASTER, NY\n(42.892784, -78.676417)'),
#  (135, 1995, '1996-01-19 00:00:00.000000', 'Esterline, Norma K.', 'Chautauqua', 'CLYMER', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'CLYMER, NY\n(42.02082, -79.629966)'),
#  (136, 1994, '1995-01-27 00:00:00.000000', 'Woodward Pipeline, Inc.', 'Erie', 'EDEN', 'BRANT-EDEN', 'MEDINA', 0, 0, 22, 0, 0, 0, 'NO', 0, 11149, 109, 8476, 'GX', 'EDEN, NY\n(42.652413, -78.896936)'),
#  (137, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Cattaraugus', 'DAYTON', 'DAYTON', 'ONONDAGA', 0, 0, 4, 0, 0, 0, 'NO', 0, 23559, 0, 22539, 'GK', 'DAYTON, NY\n(42.399022, -79.003431)'),
#  (138, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'EDEN', 'BRANT-EDEN', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 885, 0, 597, 'GK', 'EDEN, NY\n(42.652413, -78.896936)'),
#  (139, 1994, '1995-05-04 00:00:00.000000', 'U S Energy Development Corp.', 'Chautauqua', 'SHERIDAN', 'LAKESHORE', 'MEDINA', 0, 0, 0, 2, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'SHERIDAN, NY\n(42.485764, -79.241801)'),
#  (140, 1995, '1996-02-20 00:00:00.000000', 'Deptuch, Michael Estate', 'Cayuga', 'SUMMERHILL', 'SUMMERHILL', 'ORISKANY', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'SUMMERHILL, NY\n(42.638901, -76.326103)'),
#  (141, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'WALES', 'WALES', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 156, 0, 0, 'GK', 'WALES, NY\n(42.709353, -78.577478)'),
#  (142, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'ELMA', 'ELMA', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 574, 0, 574, 'GK', 'ELMA, NY\n(42.822476, -78.636722)'),
#  (143, 1994, '1995-09-03 00:00:00.000000', 'Terra Energy', 'Chautauqua', 'SHERIDAN', 'LAKESHORE', 'MEDINA', 0, 0, 8, 0, 0, 0, 'NO', 0, 23658, 767, 23458, 'GK', 'SHERIDAN, NY\n(42.485764, -79.241801)'),
#  (144, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'HAMBURG', 'ORCHARD PARK-HAMBURG', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1195, 1, 1195, 'GK', 'HAMBURG, NY\n(42.723291, -78.839026)'),
#  (145, 1995, '1996-03-04 00:00:00.000000', '20 Bliss Street, Inc.', 'Erie', 'BRANT', 'BRANT-EDEN', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 2817, 0, 2817, 'GK', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (146, 1995, '1996-03-25 00:00:00.000000', 'Demambro, Gene Brian', 'Chautauqua', 'PORTLAND', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 190, 0, 0, None, 'PORTLAND, NY\n(42.379838, -79.467344)'),
#  (147, 1995, '1996-01-16 00:00:00.000000', 'Campfield, Arthur', 'Steuben', 'HOWARD', 'HUNGRY HOLLOW', 'ORISKANY', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'HOWARD, NY\n(42.363282, -77.516098)'),
#  (148, 1995, '1996-01-26 00:00:00.000000', 'Braun, Thomas R. & Judith Ann', 'Erie', 'MARILLA', 'COWLESVILLE', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'MARILLA, NY\n(42.840165, -78.555271)'),
#  (149, 1995, '1996-09-02 00:00:00.000000', 'Basic Energy Producers, Inc.', 'Chautauqua', 'PORTLAND', 'LAKESHORE', 'MEDINA', 0, 0, 5, 0, 0, 0, 'NO', 0, 8288, 0, 8288, 'GK', 'PORTLAND, NY\n(42.379838, -79.467344)'),
#  (150, 1994, '1995-03-24 00:00:00.000000', 'Symbol Oil Corp.', 'Genesee', 'PEMBROKE', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 9293, 0, 9089, 'GK', 'PEMBROKE, NY\n(42.997549, -78.435048)'),
#  (151, 1994, '1995-03-30 00:00:00.000000', 'Whiting Well Partnership', 'Erie', 'NEWSTEAD', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 1, 1, 0, 0, 'NO', 0, 51985, 50, 6207, 'GX', 'NEWSTEAD, NY\n(43.021136, -78.495603)'),
#  (152, 1994, '1995-01-19 00:00:00.000000', 'Rudnik, Florian & Carol', 'Erie', 'MARILLA', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'MARILLA, NY\n(42.840165, -78.555271)'),
#  (153, 1995, '1996-01-23 00:00:00.000000', 'Clarion Oil & Gas Corp.', 'Chautauqua', 'CHAUTAUQUA', 'LAKESHORE', 'MEDINA', 0, 0, 0, 2, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'CHAUTAUQUA, NY\n(42.251704, -79.501693)'),
#  (154, 1994, '1995-06-04 00:00:00.000000', 'Transfuel Resources Co.', 'Chautauqua', 'POMFRET', 'LAKESHORE', 'MEDINA', 0, 0, 5, 1, 0, 0, 'NO', 0, 15670, 55, 15670, 'GK', 'POMFRET, NY\n(42.439996, -79.331441)'),
#  (155, 1995, '1996-09-02 00:00:00.000000', 'Alcott, C. Keith', 'Oneida', 'SANGERFIELD', 'UNNAMED', 'HERKIMER', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'SANGERFIELD, NY\n(42.894289, -75.370637)'),
#  (156, 1995, '1996-04-04 00:00:00.000000', 'Belden & Blake Corporation', 'Erie', 'BRANT', 'LAKEVIEW', 'MEDINA', 0, 0, 6, 0, 0, 0, 'YES', 0, 10299, 779, 10299, 'GX', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (157, 1994, '1995-08-08 00:00:00.000000', 'Snyder, E. Mark', 'Chautauqua', 'PORTLAND', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 3440, 0, 3440, 'GK', 'PORTLAND, NY\n(42.379838, -79.467344)'),
#  (158, 1994, '1995-02-14 00:00:00.000000', 'Parmelee, Terrence G. E.', 'Chautauqua', 'ELLERY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 150, 0, 0, None, 'ELLERY, NY\n(42.159868, -79.393216)'),
#  (159, 1995, '1996-02-04 00:00:00.000000', 'Cotton Well Drilling Company,  Inc.', 'Erie', 'EDEN', 'BRANT-EDEN', 'MEDINA', 0, 0, 20, 0, 0, 0, 'NO', 0, 22803, 295, 19096, 'GK', 'EDEN, NY\n(42.652413, -78.896936)'),
#  (160, 1995, '1996-09-02 00:00:00.000000', 'Basic Energy Producers, Inc.', 'Chautauqua', 'SHERIDAN', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 673, 0, 673, 'GK', 'SHERIDAN, NY\n(42.485764, -79.241801)'),
#  (161, 1994, '1995-01-30 00:00:00.000000', 'Springville-Griffith Institute Central School Dist', 'Erie', 'CONCORD', 'SARDINIA', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 5432, 0, 0, None, 'CONCORD, NY\n(42.535259, -78.731387)'),
#  (162, 1995, '1996-11-26 00:00:00.000000', 'Bower, Edwin L.', 'Livingston', 'PORTAGE', 'HUNT HOLLOW', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'PORTAGE, NY\n(42.546932, -77.994175)'),
#  (163, 1994, '1995-01-18 00:00:00.000000', 'Scott, Glenn H.', 'Chautauqua', 'VILLENOVA', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'VILLENOVA, NY\n(42.391743, -79.119456)'),
#  (164, 1995, '1996-02-04 00:00:00.000000', 'Cotton Well Drilling Company,  Inc.', 'Chautauqua', 'WESTFIELD', 'LAKESHORE', 'MEDINA', 0, 0, 10, 0, 0, 0, 'NO', 0, 14389, 605, 14179, 'GK', 'WESTFIELD, NY\n(42.324884, -79.573821)'),
#  (165, 1994, '1995-09-11 00:00:00.000000', 'Renard Drilling Co.', 'Allegany', 'BOLIVAR', 'CERES', 'RICHBURG', 0, 2, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'BOLIVAR, NY\n(42.066701, -78.167667)'),
#  (166, 1994, '1995-06-04 00:00:00.000000', 'Transfuel Resources Co.', 'Chautauqua', 'SHERIDAN', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 703, 0, 703, 'GK', 'SHERIDAN, NY\n(42.485764, -79.241801)'),
#  (167, 1994, '1995-03-24 00:00:00.000000', 'Subsea Oil & Gas, Inc.', 'Genesee', 'PEMBROKE', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 7, 1, 0, 0, 'NO', 0, 23407, 25, 22999, 'GK', 'PEMBROKE, NY\n(42.997549, -78.435048)'),
#  (168, 1994, '1995-02-17 00:00:00.000000', 'Potter Oil Co.', 'Allegany', 'INDEPENDENCE', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 26, 1, 0, 0, 0, 0, 'NO', 924, 3858, 0, 3858, 'GK,OC', 'INDEPENDENCE, NY\n(42.088045, -77.781386)'),
#  (169, 1995, '1996-04-04 00:00:00.000000', 'Belden & Blake Corporation', 'Chautauqua', 'NORTH HARMONY', 'NORTH HARMONY', 'BASS ISLAND', 1, 0, 0, 0, 0, 0, 'NO', 96, 0, 160, 0, 'OA', 'NORTH HARMONY, NY\n(42.094296, -79.374999)'),
#  (170, 1995, '1996-09-02 00:00:00.000000', 'Cordova Resources, Inc.', 'Cattaraugus', 'CARROLLTON', 'CHIPMUNK', 'CHIPMUNK', 0, 19, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (171, 1994, '1995-03-20 00:00:00.000000', 'Universal Resources Holdings, Incorporated', 'Chautauqua', 'WESTFIELD', 'LAKESHORE', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 13528, 0, 13528, 'GK', 'WESTFIELD, NY\n(42.324884, -79.573821)'),
#  (172, 1995, '1996-02-21 00:00:00.000000', 'Cabot Oil & Gas Corp.', 'Cattaraugus', 'NAPOLI', 'LAKESHORE', 'MEDINA', 0, 0, 1, 1, 0, 0, 'NO', 0, 1985, 0, 1985, 'GH', 'NAPOLI, NY\n(42.199847, -78.891869)'),
#  (173, 1995, '1996-02-04 00:00:00.000000', 'Cotton Well Drilling Company,  Inc.', 'Erie', 'CONCORD', 'CONCORD', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 3394, 55, 2344, 'GK', 'CONCORD, NY\n(42.535259, -78.731387)'),
#  (174, 1995, '1996-03-26 00:00:00.000000', 'Columbia Natural Resources  LLC', 'Chautauqua', 'CHARLOTTE', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'INACTIVE', 0, 2752, 110, 2752, 'GX', 'CHARLOTTE, NY\n(43.255001, -77.617203)'),
#  (175, 1994, '1995-08-02 00:00:00.000000', 'Union Springs School District', 'Cayuga', 'SPRINGPORT', 'WEST AUBURN', 'QUEENSTON', 0, 0, 2, 0, 0, 0, 'YES', 0, 9916, 0, 0, None, 'SPRINGPORT, NY\n(42.842233, -76.691958)'),
#  (176, 1994, '1995-05-04 00:00:00.000000', 'United States Gypsum Co.', 'Genesee', 'ELBA', 'INDIAN FALLS', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1125, 182, 1125, 'GR', 'ELBA, NY\n(43.077511, -78.187269)'),
#  (177, 1995, '1996-04-04 00:00:00.000000', 'Belden & Blake Corporation', 'Erie', 'CONCORD', 'CONCORD', 'MEDINA', 0, 0, 13, 0, 0, 0, 'YES', 0, 14966, 0, 14966, 'GX', 'CONCORD, NY\n(42.535259, -78.731387)'),
#  (178, 1994, '1995-05-04 00:00:00.000000', 'United States Gypsum Co.', 'Genesee', 'DARIEN', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 14, 0, 0, 0, 'NO', 0, 54171, 305, 52633, 'GR', 'DARIEN, NY\n(42.902048, -78.350767)'),
#  (179, 1994, '1995-07-04 00:00:00.000000', 'Vineyard Oil & Gas Company', 'Chautauqua', 'SHERMAN', 'LAKESHORE', 'MEDINA', 0, 0, 5, 0, 0, 0, 'NO', 0, 9286, 685, 9286, 'GH', 'SHERMAN, NY\n(42.159351, -79.595176)'),
#  (180, 1994, '1995-08-02 00:00:00.000000', 'Yorel Energy, Inc.', 'Genesee', 'LE ROY', 'UHLEY CORNERS-CALEDONIA', 'MEDINA', 0, 0, 5, 0, 0, 0, 'NO', 0, 6720, 36, 6664, 'GX', 'LE ROY, NY\n(42.977677, -77.987588)'),
#  (181, 1994, '1995-03-14 00:00:00.000000', 'Pennsylvania General Energy', 'Cattaraugus', 'CARROLLTON', 'BRADFORD', 'CHIPMUNK', 246, 0, 0, 0, 0, 0, 'NO', 21833, 21833, 2183, 0, 'OC', 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (182, 1995, '1996-02-22 00:00:00.000000', 'Cooper, Elton C', 'Allegany', 'ANDOVER', 'FULMER VALLEY', 'FULMER VALLEY', 0, 16, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'ANDOVER, NY\n(42.156405, -77.795231)'),
#  (183, 1994, '1995-05-04 00:00:00.000000', 'Oil, Gas & Land Services, Inc.', 'Chautauqua', 'CHERRY CREEK', 'LAKESHORE', 'MEDINA', 0, 0, 10, 1, 0, 0, 'NO', 0, 13621, 285, 13043, 'GC,GX', 'CHERRY CREEK, NY\n(42.296322, -79.099108)'),
#  (184, 1995, '1996-07-05 00:00:00.000000', 'County Line Stone Co., Inc.', 'Erie', 'NEWSTEAD', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 0, 2, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'NEWSTEAD, NY\n(43.021136, -78.495603)'),
#  (185, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Chautauqua', 'NORTH HARMONY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1773, 0, 1773, 'GX', 'NORTH HARMONY, NY\n(42.094296, -79.374999)'),
#  (186, 1995, '1996-05-15 00:00:00.000000', 'Eagle Oil Field Supply, Inc. d/b/a Eagle S & T', 'Chautauqua', 'BUSTI', 'BUSTI', 'GLADE', 53, 0, 0, 0, 0, 0, 'NO', 859, 0, 0, 0, 'OC', 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (187, 1995, '1996-12-09 00:00:00.000000', 'Cunningham Natural Gas Corp.', 'Onondaga', 'CAMILLUS', 'DRY WILDCAT', None, 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'CAMILLUS, NY\n(43.038991, -76.3076)'),
#  (188, 1994, '1995-03-23 00:00:00.000000', 'Seneca Resources Corporation', 'Chautauqua', 'ELLICOTT', 'LAKESHORE', 'MEDINA', 0, 0, 10, 0, 0, 0, 'NO', 0, 74496, 40, 73218, 'GK', 'ELLICOTT, NY\n(42.734402, -78.731697)'),
#  (189, 1994, '1995-02-02 00:00:00.000000', 'Tiffany, Glenn O', 'Tioga', 'OWEGO', 'CAFFERTY HILL', 'MARCELLUS', 0, 0, 1, 0, 0, 0, 'YES', 0, 73, 0, 0, None, 'OWEGO, NY\n(42.103237, -76.263163)'),
#  (190, 1995, '1996-12-09 00:00:00.000000', 'Conti, John A.', 'Chautauqua', 'BUSTI', 'BUSTI', 'GLADE', 3, 0, 0, 0, 0, 0, 'NO', 25, 0, 18, 0, 'OC', 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (191, 1995, '1996-09-01 00:00:00.000000', 'Arkema Inc.', 'Erie', 'TONAWANDA', 'TONAWANDA', 'MEDINA', 0, 0, 2, 0, 0, 0, 'YES', 0, 794, 0, 0, None, 'TONAWANDA, NY\n(43.016642, -78.878854)'),
#  (192, 1994, '1995-10-03 00:00:00.000000', 'Venture Technology, Inc.', 'Chautauqua', 'POMFRET', 'LAKESHORE', 'MEDINA', 0, 0, 0, 2, 0, 0, 'INACTIVE', 0, 0, 0, 0, 'GK', 'POMFRET, NY\n(42.439996, -79.331441)'),
#  (193, 1994, '1995-03-20 00:00:00.000000', 'Universal Resources Holdings, Incorporated', 'Chautauqua', 'VILLENOVA', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 2254, 0, 2254, 'GK', 'VILLENOVA, NY\n(42.391743, -79.119456)'),
#  (194, 1994, '1995-06-04 00:00:00.000000', 'Reynolds, James W', 'Allegany', 'WELLSVILLE', 'FULMER VALLEY', 'FULMER VALLEY', 0, 8, 0, 0, 0, 0, None, 0, 0, 0, 0, None, 'WELLSVILLE, NY\n(42.120693, -77.946058)'),
#  (195, 1995, '1996-02-20 00:00:00.000000', 'Alden Aurora Gas Co.,  Inc.', 'Erie', 'LANCASTER', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 130, 0, 0, None, 'LANCASTER, NY\n(42.892784, -78.676417)'),
#  (196, 1994, '1995-03-23 00:00:00.000000', 'Taylor, Gilbert M', 'Allegany', 'BOLIVAR', 'RICHBURG', 'RICHBURG', 0, 0, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'BOLIVAR, NY\n(42.066701, -78.167667)'),
#  (197, 1995, '1996-03-19 00:00:00.000000', 'Arlington Exploration Co.', 'Steuben', 'BATH', 'THOMAS CORNERS', 'ONONDAGA', 0, 0, 2, 0, 0, 0, 'NO', 0, 24306, 2, 24306, 'GH', 'BATH, NY\n(42.337015, -77.317992)'),
#  (198, 1994, '1995-02-14 00:00:00.000000', 'White, Walter W. & Christina L.', 'Cattaraugus', 'CARROLLTON', 'CHIPMUNK', 'BRADFORD', 2, 0, 0, 0, 0, 0, 'NO', 118, 0, 0, 0, 'OA', 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (199, 1994, '1995-03-17 00:00:00.000000', 'Richardson Petroleum Corp.', 'Allegany', 'INDEPENDENCE', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 127, 0, 0, 0, 12, 0, 'NO', 12731, 75939, 8235, 75939, 'GK,OC', 'INDEPENDENCE, NY\n(42.088045, -77.781386)'),
#  (200, 1995, '1996-01-17 00:00:00.000000', 'Bemus Point Central School District', 'Chautauqua', 'ELLERY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 164, 0, 0, None, 'ELLERY, NY\n(42.159868, -79.393216)'),
#  (201, 1994, '1995-03-30 00:00:00.000000', 'Pan Energy Company, Inc.', 'Cattaraugus', 'NAPOLI', 'LAKESHORE', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 1780, 0, 1380, 'GK', 'NAPOLI, NY\n(42.199847, -78.891869)'),
#  (202, 1995, '1996-03-28 00:00:00.000000', 'Chautauqua Energy, Inc.', 'Chautauqua', 'GERRY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1647, 10, 1447, 'GK', 'GERRY, NY\n(42.194749, -79.250394)'),
#  (203, 1995, '1996-12-09 00:00:00.000000', 'Cunningham Natural Gas Corp.', 'Steuben', 'ADDISON', 'DRY WILDCAT', None, 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'ADDISON, NY\n(42.105085, -77.23433)'),
#  (204, 1995, '1996-04-17 00:00:00.000000', 'Ardent Resources, Inc.', 'Madison', 'LEBANON', 'LEBANON', 'HERKIMER-ONEIDA', 0, 0, 3, 0, 0, 0, 'NO', 0, 43651, 0, 43651, 'GH', 'LEBANON, NY\n(42.780748, -75.647667)'),
#  (205, 1994, '1995-01-19 00:00:00.000000', 'Skubis, Daniel J.', 'Chautauqua', 'POMFRET', 'LAKESHORE', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'POMFRET, NY\n(42.439996, -79.331441)'),
#  (206, 1994, '1995-03-22 00:00:00.000000', 'Weil Resources, Inc.', 'Erie', 'EVANS', 'LAKEVIEW', 'MEDINA', 0, 0, 10, 2, 0, 0, 'NO', 0, 19085, 95, 18677, 'GK', 'EVANS, NY\n(42.638457, -79.027689)'),
#  (207, 1994, '1995-01-30 00:00:00.000000', 'Northrop, John H.', 'Oneida', 'SANGERFIELD', 'SANGERFIELD', 'HERKIMER', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'SANGERFIELD, NY\n(42.894289, -75.370637)'),
#  (208, 1995, '1996-02-04 00:00:00.000000', 'Cotton Well Drilling Company,  Inc.', 'Chautauqua', 'SHERMAN', 'LAKESHORE', 'MEDINA', 0, 0, 5, 0, 0, 0, 'NO', 0, 6770, 435, 5780, 'GK', 'SHERMAN, NY\n(42.159351, -79.595176)'),
#  (209, 1995, '2001-08-15 00:00:00.000000', 'Dannic Energy Corp.', 'Chautauqua', 'CARROLL', 'LAKESHORE', 'MEDINA', 0, 0, 25, 2, 0, 0, 'NO', 0, 32918, 0, 32918, 'GH', 'CARROLL, NY\n(42.054174, -79.15832)'),
#  (210, 1995, '1996-02-04 00:00:00.000000', 'Cotton Well Drilling Company,  Inc.', 'Erie', 'BOSTON', 'BRANT-EDEN', 'MEDINA', 0, 0, 10, 0, 0, 0, 'NO', 0, 10532, 65, 8018, 'GK', 'BOSTON, NY\n(42.623202, -78.731581)'),
#  (211, 1995, '1996-04-17 00:00:00.000000', 'Bkg Truck Repair, LLC', 'Cattaraugus', 'COLD SPRING', 'HOTCHKISS HOLLOW', 'UPPER DEVONIAN', 0, 0, 0, 5, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'COLD SPRING, NY\n(41.420041, -73.954774)'),
#  (212, 1994, '1995-03-02 00:00:00.000000', 'Randall, John B.', 'Ontario', 'RICHMOND', 'WEST BLOOMFIELD', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 160, 0, 0, None, 'RICHMOND, NY\n(42.790065, -77.516695)'),
#  (213, 1995, '1996-10-01 00:00:00.000000', 'Estate of Robert Gloor', 'Chautauqua', 'POMFRET', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'POMFRET, NY\n(42.439996, -79.331441)'),
#  (214, 1994, '1995-04-28 00:00:00.000000', 'Wasson/Regis Oil Company', 'Allegany', 'BOLIVAR', 'RICHBURG', 'RICHBURG', 27, 11, 0, 0, 0, 0, 'NO', 93, 0, 0, 0, 'OC', 'BOLIVAR, NY\n(42.066701, -78.167667)'),
#  (215, 1994, '1995-01-27 00:00:00.000000', 'Woodward Pipeline, Inc.', 'Erie', 'NORTH COLLINS', 'NORTH COLLINS', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 1300, 13, 328, 'GX', 'NORTH COLLINS, NY\n(42.595159, -78.940951)'),
#  (216, 1995, '1996-06-03 00:00:00.000000', 'Estate of Thomas K. Faulkner', 'Cattaraugus', 'ALLEGANY', 'BRADFORD', 'BRADFORD', 2, 0, 0, 0, 0, 0, 'NO', 46, 0, 0, 0, 'OA', 'ALLEGANY, NY\n(42.088061, -78.491258)'),
#  (217, 1994, '1995-01-20 00:00:00.000000', 'Shearing, David H.', 'Wyoming', 'PERRY', 'LEICESTER', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 186, 0, 186, 'GK', 'PERRY, NY\n(42.719701, -78.000751)'),
#  (218, 1994, '1995-01-19 00:00:00.000000', 'Weber, Richard', 'Erie', 'TONAWANDA', 'BUFFALO', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'TONAWANDA, NY\n(43.016642, -78.878854)'),
#  (219, 1994, '1995-09-03 00:00:00.000000', 'Yahn & Yahn, Inc.', 'Allegany', 'INDEPENDENCE', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 13, 5, 0, 0, 0, 0, 'NO', 836, 130, 945, 0, 'OC', 'INDEPENDENCE, NY\n(42.088045, -77.781386)'),
#  (220, 1994, '1995-05-04 00:00:00.000000', 'Walter C. Guthrie & Sons', 'Wyoming', 'COVINGTON', 'LEICESTER', 'MEDINA', 0, 0, 2, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'COVINGTON, NY\n(42.853421, -78.010388)'),
#  (221, 1994, '1995-02-14 00:00:00.000000', 'Patterson, Robert', 'Chautauqua', 'PORTLAND', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 270, 0, 0, None, 'PORTLAND, NY\n(42.379838, -79.467344)'),
#  (222, 1994, '1995-03-28 00:00:00.000000', 'Shelex Drilling, Inc.', 'Chautauqua', 'NORTH HARMONY', 'NORTH HARMONY', 'ONONDAGA-BASS ISLAND', 2, 0, 0, 0, 0, 0, 'NO', 278, 0, 205, 0, 'OB', 'NORTH HARMONY, NY\n(42.094296, -79.374999)'),
#  (223, 1994, '1995-02-22 00:00:00.000000', 'Pennzoil Products Co.', 'Cattaraugus', 'CARROLLTON', 'CHIPMUNK', 'CHIPMUNK', 0, 24, 0, 0, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (224, 1995, '1996-09-01 00:00:00.000000', 'Cady, Merle E.', 'Chautauqua', 'SHERMAN', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'SHERMAN, NY\n(42.159351, -79.595176)'),
#  (225, 1994, '1995-02-13 00:00:00.000000', 'Vandermark Exploration, Inc.', 'Allegany', 'SCIO', 'GORDON BROOK', 'ORISKANY', 0, 0, 6, 1, 0, 0, 'NO', 0, 39246, 3454, 38554, 'GH', 'SCIO, NY\n(42.171429, -77.97865)'),
#  (226, 1995, '1996-02-22 00:00:00.000000', 'Cal Ban Corp.', 'Cattaraugus', 'ALLEGANY', 'FIVE MILE', 'BRADFORD', 110, 0, 0, 0, 0, 0, 'NO', 4698, 4698, 513, 0, 'OA', 'ALLEGANY, NY\n(42.088061, -78.491258)'),
#  (227, 1995, '1996-04-17 00:00:00.000000', 'Ardent Resources, Inc.', 'Ontario', 'GENEVA', 'BENTON RUN', 'MEDINA', 0, 0, 2, 1, 0, 0, 'NO', 0, 1241, 0, 1241, 'GK', 'GENEVA, NY\n(42.867972, -76.985573)'),
#  (228, 1995, '1996-04-04 00:00:00.000000', 'Belden & Blake Corporation', 'Chautauqua', 'SHERIDAN', 'LAKESHORE', 'MEDINA', 0, 0, 14, 3, 0, 0, 'YES', 0, 22308, 390, 22308, 'GX', 'SHERIDAN, NY\n(42.485764, -79.241801)'),
# ...
#  (923, 1971, '1994-09-23 00:00:00.000000', 'Consolidated Gas Supply Corp.', 'Wyoming', 'COVINGTON', 'LEICESTER', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 2317, 0, 2317, 'GX', 'COVINGTON, NY\n(42.853421, -78.010388)'),
#  (924, 1971, '1994-09-23 00:00:00.000000', 'Cusimano, Sam', 'Chautauqua', 'BUSTI', 'BUSTI', 'GLADE', 2, 0, 0, 0, 0, 0, 'NO', 21, 0, 0, 0, 'OB', 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (925, 1995, '1996-05-03 00:00:00.000000', 'Mathis, Edna Joyce', 'Erie', 'ELMA', 'ELMA', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 218, 0, 0, None, 'ELMA, NY\n(42.822476, -78.636722)'),
#  (926, 1995, '1996-02-20 00:00:00.000000', 'T.M. Quaintance Crude Oil Production', 'Allegany', 'ALMA', 'RICHBURG', 'RICHBURG', 33, 0, 0, 0, 4, 0, 'NO', 626, 0, 23, 0, 'OC', 'ALMA, NY\n(42.012207, -78.060759)'),
#  (927, 1995, '1996-11-01 00:00:00.000000', 'Sena, Joseph R', 'Chautauqua', 'CHAUTAUQUA', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 85, 0, 0, None, 'CHAUTAUQUA, NY\n(42.251704, -79.501693)'),
#  (928, 1995, '1996-04-04 00:00:00.000000', 'Frey Well Drilling, Inc.', 'Erie', 'WALES', 'BUFFALO CREEK', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'WALES, NY\n(42.709353, -78.577478)'),
#  (929, 1995, '1996-04-17 00:00:00.000000', 'Remington, Donald', 'Cattaraugus', 'CARROLLTON', 'CHIPMUNK', 'CHIPMUNK', 0, 0, 1, 3, 0, 0, 'NO', 17, 0, 0, 0, 'OC', 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (930, 1995, '1996-02-04 00:00:00.000000', 'Zielinski, Jason H.', 'Chautauqua', 'ARKWRIGHT', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'ARKWRIGHT, NY\n(42.406943, -79.236356)'),
#  (931, 1995, '1996-08-04 00:00:00.000000', 'Resource America, Inc.', 'Chautauqua', 'SHERMAN', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 4170, 302, 4170, 'GH', 'SHERMAN, NY\n(42.159351, -79.595176)'),
#  (932, 1995, '1996-02-27 00:00:00.000000', 'Noble, Ray A.', 'Yates', 'BENTON', 'NORTH PENN YAN', 'QUEENSTON', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'BENTON, NY\n(42.717561, -77.049243)'),
#  (933, 1995, '1996-10-24 00:00:00.000000', 'Vineyard Oil & Gas Company', 'Chautauqua', 'RIPLEY', 'LAKESHORE', 'MEDINA', 0, 0, 13, 0, 0, 0, 'NO', 0, 27779, 0, 27779, 'GK', 'RIPLEY, NY\n(42.266859, -79.710476)'),
#  (934, 1995, '1996-01-04 00:00:00.000000', 'Lomak Operating Company', 'Chautauqua', 'PORTLAND', 'LAKESHORE', 'MEDINA', 0, 0, 9, 0, 0, 0, 'NO', 0, 13811, 0, 13811, 'GK', 'PORTLAND, NY\n(42.379838, -79.467344)'),
#  (935, 1995, '1996-03-29 00:00:00.000000', 'Subsea Oil & Gas, Inc.', 'Erie', 'HAMBURG', 'LAKESHORE', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'HAMBURG, NY\n(42.723291, -78.839026)'),
#  (936, 1995, '1996-04-04 00:00:00.000000', 'L. W. Resources', 'Erie', 'EVANS', 'LAKEVIEW', 'MEDINA', 0, 0, 3, 2, 0, 0, 'NO', 0, 2742, 0, 2742, 'GK', 'EVANS, NY\n(42.638457, -79.027689)'),
#  (937, 1995, '1996-01-18 00:00:00.000000', 'Peterson, Donald W. & L. Janet', 'Chautauqua', 'SHERMAN', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'SHERMAN, NY\n(42.159351, -79.595176)'),
#  (938, 1995, '1996-03-29 00:00:00.000000', 'Trahan Petroleum, Inc.', 'Chautauqua', 'ELLINGTON', 'LAKESHORE', 'MEDINA', 0, 0, 106, 12, 0, 0, 'NO', 0, 118035, 0, 111720, 'GH,GK', 'ELLINGTON, NY\n(42.215868, -79.108075)'),
#  (939, 1995, '1996-01-18 00:00:00.000000', 'Southwestern Central School District', 'Chautauqua', 'ELLICOTT', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 678, 41, 0, None, 'ELLICOTT, NY\n(42.734402, -78.731697)'),
#  (940, 1995, '1996-03-27 00:00:00.000000', 'Seneca Resources Corporation', 'Chautauqua', 'POLAND', 'SPRAGUE HILL', 'ONONDAGA', 0, 0, 2, 0, 0, 0, 'NO', 0, 10336, 0, 10132, 'GK', 'POLAND, NY\n(43.226463, -75.062063)'),
#  (941, 1995, '1996-04-04 00:00:00.000000', 'Trahan Petroleum, Inc.', 'Chautauqua', 'NORTH HARMONY', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 330, 0, 101, 'GH', 'NORTH HARMONY, NY\n(42.094296, -79.374999)'),
#  (942, 1995, '1996-03-27 00:00:00.000000', 'Seneca Resources Corporation', 'Cattaraugus', 'PERSIA', 'LAKESHORE', 'MEDINA', 0, 0, 6, 1, 0, 0, 'NO', 0, 9801, 0, 9475, 'GK', 'PERSIA, NY\n(42.384131, -78.936278)'),
#  (943, 1995, '1996-03-29 00:00:00.000000', 'Pan Energy Company, Inc.', 'Cattaraugus', 'CONEWANGO', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 4284, 0, 4084, 'GK', 'CONEWANGO, NY\n(42.238697, -79.031066)'),
#  (944, 1995, '1996-04-16 00:00:00.000000', 'Perkins & Gondree', 'Erie', 'BRANT', 'BRANT-EDEN', 'MEDINA', 0, 0, 3, 1, 0, 0, 'NO', 0, 5627, 5, 5627, 'GK', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (945, 1995, '1996-01-03 00:00:00.000000', 'Heath, Francis A. & Ruth E. Heath', 'Cattaraugus', 'DAYTON', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 379, 0, 0, None, 'DAYTON, NY\n(42.399022, -79.003431)'),
#  (946, 1995, '1996-02-27 00:00:00.000000', 'Price, Murry', 'Chautauqua', 'CHAUTAUQUA', 'LAKESHORE', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 5376, 40, 5176, 'GK', 'CHAUTAUQUA, NY\n(42.251704, -79.501693)'),
#  (947, 1995, '1996-09-05 00:00:00.000000', 'Energy Control Unlimited, Inc.', 'Erie', 'BRANT', 'BRANT-EDEN', 'MEDINA', 0, 0, 7, 2, 0, 0, 'NO', 0, 11897, 95, 10654, 'GK', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (948, 1995, '1996-01-24 00:00:00.000000', 'Stiegler, Richard M', 'Erie', 'CHEEKTOWAGA', 'BUFFALO', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 530, 0, 0, None, 'CHEEKTOWAGA, NY\n(42.907071, -78.754318)'),
#  (949, 1995, '2001-08-22 00:00:00.000000', 'Seneca Resources Corporation', 'Allegany', 'ALMA', None, None, 0, 0, 0, 0, 0, 0, None, 0, 0, 0, 0, None, 'ALMA, NY\n(42.012207, -78.060759)'),
#  (950, 1995, '1996-08-04 00:00:00.000000', 'Schreiner Oil and Gas Inc.', 'Erie', 'AURORA', 'ELMA', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1395, 0, 1395, 'GX', 'AURORA, NY\n(42.753982, -76.70241)'),
#  (951, 1995, '1996-12-03 00:00:00.000000', 'Lenape Resources, Inc.', 'Livingston', 'CALEDONIA', 'FINNEGAN HILL', 'MEDINA', 0, 0, 10, 0, 0, 0, 'NO', 0, 20174, 0, 20034, 'GK', 'CALEDONIA, NY\n(42.973152, -77.855225)'),
#  (952, 1995, '1996-03-19 00:00:00.000000', 'Gemini Oil Company', 'Chautauqua', 'BUSTI', 'BUSTI', 'GLADE', 23, 0, 0, 0, 0, 0, 'NO', 232, 116, 76, 0, 'OC', 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (953, 1995, '1996-01-31 00:00:00.000000', 'Sherwood, Helen', 'Cattaraugus', 'ALLEGANY', 'CHIPMUNK', 'CHIPMUNK', 9, 0, 0, 0, 0, 0, 'NO', 6, 0, 1, 0, 'OC', 'ALLEGANY, NY\n(42.088061, -78.491258)'),
#  (954, 1995, '1996-01-03 00:00:00.000000', 'Hopewell Oil & Gas, Inc.', 'Allegany', 'WIRT', 'RICHBURG', 'RICHBURG', 14, 0, 0, 0, 0, 0, 'NO', 35, 0, 0, 0, 'OC', 'WIRT, NY\n(42.137408, -78.150594)'),
#  (955, 1995, '1996-03-29 00:00:00.000000', 'Symbol Oil Corp.', 'Erie', 'ELMA', 'BUFFALO CREEK', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 2870, 30, 2870, 'GK', 'ELMA, NY\n(42.822476, -78.636722)'),
#  (956, 1995, '1996-01-04 00:00:00.000000', 'Lomak Operating Company', 'Chautauqua', 'BUSTI', 'LAKESHORE', 'MEDINA', 0, 0, 3, 3, 0, 0, 'NO', 0, 2507, 28, 2507, 'GK', 'BUSTI, NY\n(42.038067, -79.283549)'),
#  (957, 1995, '1996-01-26 00:00:00.000000', 'Perry Central Schools', 'Wyoming', 'PERRY', 'SILVER LAKE', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'PERRY, NY\n(42.719701, -78.000751)'),
#  (958, 1995, '1996-04-17 00:00:00.000000', 'Young, Douglas V.', 'Allegany', 'SCIO', 'RICHBURG', 'RICHBURG', 0, 32, 0, 0, 21, 0, 'INACTIVE', 0, 0, 0, 0, None, 'SCIO, NY\n(42.171429, -77.97865)'),
#  (959, 1995, '1996-02-04 00:00:00.000000', 'United States Gypsum Co.', 'Wyoming', 'BENNINGTON', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 5, 0, 0, 0, None, 0, 18470, 63, 18241, 'GR', 'BENNINGTON, NY\n(42.837023, -78.397809)'),
#  (960, 1995, '1997-01-22 00:00:00.000000', 'Oily Ann Oil And Gas Inc.', 'Cattaraugus', 'OLEAN', 'OLEAN', 'MEDINA', 1, 0, 0, 0, 0, 0, 'NO', 0, 0, 0, 0, 'OC', 'OLEAN, NY\n(42.077495, -78.429849)'),
#  (961, 1995, '1996-03-04 00:00:00.000000', 'GFS Energy, Inc.', 'Genesee', 'DARIEN', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 4, 0, 0, 0, 'NO', 0, 11721, 0, 11276, 'GK', 'DARIEN, NY\n(42.902048, -78.350767)'),
#  (962, 1995, '1996-03-27 00:00:00.000000', 'Seneca Resources Corporation', 'Chautauqua', 'WESTFIELD', 'LAKESHORE', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 23235, 0, 23031, 'GK', 'WESTFIELD, NY\n(42.324884, -79.573821)'),
#  (963, 1995, '1996-03-29 00:00:00.000000', 'Weil Resources, Inc.', 'Erie', 'WALES', 'CENTRAL WALES', 'ONONDAGA', 0, 0, 4, 0, 0, 0, 'NO', 0, 40, 0, 9, 'GK', 'WALES, NY\n(42.709353, -78.577478)'),
#  (964, 1995, '1996-03-04 00:00:00.000000', 'National Fuel Gas Supply Corp.', 'Allegany', 'INDEPENDENCE', 'BEECH HILL-INDEPENDENCE', 'ORISKANY', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'INDEPENDENCE, NY\n(42.088045, -77.781386)'),
#  (965, 1995, '1996-03-27 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'NEWSTEAD', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 2529, 0, 2529, 'GK', 'NEWSTEAD, NY\n(43.021136, -78.495603)'),
#  (966, 1995, '1996-02-04 00:00:00.000000', 'Oil, Gas & Land Services, Inc.', 'Chautauqua', 'CHARLOTTE', 'GERRY-CHARLOTTE', 'ONONDAGA-BASS ISLAND', 0, 0, 0, 1, 0, 0, 'YES', 0, 0, 0, 0, None, 'CHARLOTTE, NY\n(43.255001, -77.617203)'),
#  (967, 1995, '1996-08-04 00:00:00.000000', 'Schreiner Oil and Gas Inc.', 'Erie', 'ORCHARD PARK', 'EAST AURORA', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 4751, 0, 4751, 'GX', 'ORCHARD PARK, NY\n(42.767456, -78.743906)'),
#  (968, 1995, '1996-01-17 00:00:00.000000', 'Tenhuisen, Paul Calvin and Josephine', 'Chautauqua', 'CLYMER', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'CLYMER, NY\n(42.02082, -79.629966)'),
#  (969, 1995, '1996-01-04 00:00:00.000000', 'Lomak Operating Company', 'Chautauqua', 'STOCKTON', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 5196, 0, 5196, 'GK', 'STOCKTON, NY\n(42.316097, -79.359685)'),
#  (970, 1995, '1996-03-04 00:00:00.000000', 'GFS Energy, Inc.', 'Erie', 'ELMA', 'BUFFALO CREEK', 'MEDINA', 0, 0, 2, 0, 0, 0, 'NO', 0, 3308, 0, 2850, 'GK', 'ELMA, NY\n(42.822476, -78.636722)'),
#  (971, 1995, '1996-10-16 00:00:00.000000', 'Lyndon Oil Co.,Inc.', 'Cattaraugus', 'CARROLLTON', 'BRADFORD', 'BRADFORD', 8, 0, 0, 0, 0, 0, 'NO', 1665, 0, 150, 0, 'OA', 'CARROLLTON, NY\n(42.023289, -78.628438)'),
#  (972, 1971, '1994-09-29 00:00:00.000000', 'Iroquois Gas Corp.', 'Erie', 'BRANT', None, 'CLINTON', 0, 0, 1, 0, 0, 0, 'NO', 0, 153, 0, 153, 'GX', 'BRANT, NY\n(42.58859, -79.044449)'),
#  (973, 1971, '1994-09-29 00:00:00.000000', 'Iroquois Gas Corp.', 'Chautauqua', 'HANOVER', 'LAKESHORE', 'MEDINA', 0, 0, 4, 0, 0, 0, 'NO', 0, 4065, 0, 4065, 'GX', 'HANOVER, NY\n(42.9669, -75.378098)'),
#  (974, 1974, '1994-09-09 00:00:00.000000', 'Borglum, Elsie J.', 'Yates', None, None, None, 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'NY\n(42.826892, -75.544286)'),
#  (975, 1995, '1996-01-04 00:00:00.000000', 'Lomak Operating Company', 'Chautauqua', 'DUNKIRK', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 4866, 0, 4866, 'GK', 'DUNKIRK, NY\n(42.481338, -79.333958)'),
#  (976, 1995, '1996-02-04 00:00:00.000000', 'North Central Oil Corp.', 'Cattaraugus', 'LEON', 'LAKESHORE', 'MEDINA', 0, 0, 3, 0, 0, 0, 'NO', 0, 21367, 0, 20428, 'GH', 'LEON, NY\n(42.293071, -79.01636)'),
#  (977, 1995, '1996-10-01 00:00:00.000000', 'Skora, James B', 'Erie', 'NORTH COLLINS', 'NORTH COLLINS', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 250, 0, 0, None, 'NORTH COLLINS, NY\n(42.595159, -78.940951)'),
#  (978, 1995, '1996-02-04 00:00:00.000000', 'Geo Ventures, Inc.', 'Erie', 'CONCORD', 'CONCORD', 'MEDINA', 0, 0, 4, 0, 0, 0, 'NO', 0, 8970, 230, 8370, 'GK', 'CONCORD, NY\n(42.535259, -78.731387)'),
#  (979, 1995, '1996-03-27 00:00:00.000000', 'Seneca Resources Corporation', 'Erie', 'WEST SENECA', 'WEST SENECA', 'MEDINA', 0, 0, 2, 1, 0, 0, 'NO', 0, 10667, 0, 10236, 'GK', 'WEST SENECA, NY\n(42.843272, -78.790813)'),
#  (980, 1995, '1996-09-05 00:00:00.000000', 'Energy Control Unlimited, Inc.', 'Cattaraugus', 'LEON', 'LAKESHORE', 'MEDINA', 0, 0, 20, 4, 0, 0, 'NO', 0, 164283, 120, 162259, 'GH', 'LEON, NY\n(42.293071, -79.01636)'),
#  (981, 1995, '1996-10-25 00:00:00.000000', 'Rasmussen, Ronnie O.', 'Seneca', 'FAYETTE', 'FAYETTE-WATERLOO', 'QUEENSTON', 0, 0, 3, 0, 0, 0, 'NO', 0, 5624, 0, 504, 'GX', 'FAYETTE, NY\n(42.831987, -76.847469)'),
#  (982, 1995, '1996-03-04 00:00:00.000000', 'National Fuel Gas Supply Corp.', 'Cattaraugus', 'MACHIAS', 'LAKESHORE', 'MEDINA', 0, 0, 0, 2, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'MACHIAS, NY\n(42.416255, -78.493246)'),
#  (983, 1995, '1996-06-03 00:00:00.000000', 'Vandermark Exploration, Inc.', 'Steuben', 'HOWARD', 'HOWARD', 'ORISKANY', 0, 0, 1, 0, 0, 0, 'NO', 0, 2239, 0, 2239, 'GK', 'HOWARD, NY\n(42.363282, -77.516098)'),
#  (984, 1995, '1996-01-17 00:00:00.000000', 'Villafrank & Wells', 'Chautauqua', 'STOCKTON', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1124, 0, 1124, 'GK', 'STOCKTON, NY\n(42.316097, -79.359685)'),
#  (985, 1995, '1996-01-04 00:00:00.000000', 'Lomak Operating Company', 'Chautauqua', 'CHAUTAUQUA', 'LAKESHORE', 'MEDINA', 0, 0, 151, 12, 0, 0, 'NO', 0, 307920, 210, 307920, 'GH,GK', 'CHAUTAUQUA, NY\n(42.251704, -79.501693)'),
#  (986, 1995, '1996-02-04 00:00:00.000000', 'Stedman Energy, Inc.', 'Chautauqua', 'CHERRY CREEK', 'LAKESHORE', 'MEDINA', 0, 0, 6, 0, 0, 0, 'NO', 0, 12596, 220, 12196, 'GH', 'CHERRY CREEK, NY\n(42.296322, -79.099108)'),
#  (987, 1995, '1996-01-02 00:00:00.000000', 'Patterson, Robert', 'Chautauqua', 'PORTLAND', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 275, 0, 0, None, 'PORTLAND, NY\n(42.379838, -79.467344)'),
#  (988, 1995, '1996-04-04 00:00:00.000000', 'L. W. Resources', 'Chautauqua', 'GERRY', 'LAKESHORE', 'MEDINA', 0, 0, 12, 0, 0, 0, 'NO', 0, 6016, 10, 4416, 'GH', 'GERRY, NY\n(42.194749, -79.250394)'),
#  (989, 1995, '1996-01-25 00:00:00.000000', 'Smith, Richard A.', 'Chautauqua', 'CHERRY CREEK', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 0, 0, 0, None, 'CHERRY CREEK, NY\n(42.296322, -79.099108)'),
#  (990, 1995, '1996-12-03 00:00:00.000000', 'Wierzba, David P.', 'Erie', 'ELMA', 'BUFFALO CREEK', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 665, 0, 380, 'GK', 'ELMA, NY\n(42.822476, -78.636722)'),
#  (991, 1995, '1996-03-29 00:00:00.000000', 'Subsea Oil & Gas, Inc.', 'Erie', 'MARILLA', 'BUFFALO CREEK', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 2703, 40, 2703, 'GK', 'MARILLA, NY\n(42.840165, -78.555271)'),
#  (992, 1995, '1996-02-13 00:00:00.000000', 'Slater, Patricia A.', 'Erie', 'ALDEN', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'ALDEN, NY\n(42.900146, -78.4922)'),
#  (993, 1995, '1996-02-04 00:00:00.000000', 'United States Gypsum Co.', 'Genesee', 'DARIEN', 'DANLEY CORNERS', 'MEDINA', 0, 0, 25, 0, 0, 0, None, 0, 75883, 1065, 71725, 'GR', 'DARIEN, NY\n(42.902048, -78.350767)'),
#  (994, 1995, '1996-12-09 00:00:00.000000', 'Saint Barnabas R.C. Church', 'Erie', 'CHEEKTOWAGA', 'ALDEN-LANCASTER', 'MEDINA', 0, 0, 1, 1, 0, 0, 'YES', 0, 3, 0, 0, None, 'CHEEKTOWAGA, NY\n(42.907071, -78.754318)'),
#  (995, 1995, '1996-10-21 00:00:00.000000', 'Walchli, John W. Jr.', 'Allegany', 'INDEPENDENCE', 'BEECH HILL-INDEPENDENCE', 'FULMER VALLEY', 12, 0, 0, 0, 0, 0, 'NO', 386, 735, 2, 735, 'GK,OC', 'INDEPENDENCE, NY\n(42.088045, -77.781386)'),
#  (996, 1995, '1996-03-04 00:00:00.000000', 'Helmhold Oil', 'Allegany', 'WELLSVILLE', 'FULMER VALLEY', 'FULMER VALLEY', 39, 0, 0, 0, 0, 0, 'NO', 526, 0, 0, 0, 'OC', 'WELLSVILLE, NY\n(42.120693, -77.946058)'),
#  (997, 1995, '1996-10-18 00:00:00.000000', 'Lischer, Donald A', 'Erie', 'ELMA', 'ELMA', 'MEDINA', 0, 0, 1, 0, 0, 0, 'NO', 0, 1139, 0, 1046, 'GK', 'ELMA, NY\n(42.822476, -78.636722)'),
#  (998, 1995, '1996-03-04 00:00:00.000000', 'National Fuel Gas Supply Corp.', 'Genesee', 'PAVILION', 'PAVILION', 'MEDINA', 0, 0, 0, 1, 0, 0, 'INACTIVE', 0, 0, 0, 0, None, 'PAVILION, NY\n(42.876072, -78.02272)'),
#  (999, 1995, '1996-07-02 00:00:00.000000', 'St Columbans On The Lake, Inc.', 'Chautauqua', 'SHERIDAN', 'LAKESHORE', 'MEDINA', 0, 0, 1, 0, 0, 0, 'YES', 0, 1902, 40, 0, None, 'SHERIDAN, NY\n(42.485764, -79.241801)'),
#  ...]
